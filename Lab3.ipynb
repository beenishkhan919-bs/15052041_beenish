# %% [markdown]
# <a href="https://colab.research.google.com/github/beenishkhan919-bs/15052041_beenish/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

from google import genai

client = genai.Client(api_key="Beenish_apikey")

MODEL = "models/gemini-3.5-flash"


university_info = {
    "name": "Federal Urdu University of Arts, Sciences & Technology",
    "short_name": "FUUAST",
    "country": "Pakistan",
    "main_location": "Karachi",
    "website": "https://fuuast.edu.pk/"
}


campuses = {
    "Abdul Haq Campus": {
        "location": "Karachi",
        "major_faculties": [
            "Faculty of Arts",
            "Faculty of Business Administration, Commerce & Economics",
            "Faculty of Education",
            "Faculty of Islamic Studies"
        ]
    },

    "Gulshan Campus": {
        "location": "Karachi",
        "major_faculties": [
            "Faculty of Science & Technology",
            "Faculty of Pharmacy",
            "Faculty of Business Administration, Commerce & Economics",
            "Faculty of Law"
        ]
    }
}


undergraduate_programs = {

    "Faculty of Arts": [
        "BS Arabic",
        "BS English",
        "BS General History",
        "BS International Relations",
        "BS Islamic History",
        "BS Mass Communication",
        "BS Political Science",
        "BS Psychology",
        "BS Sindhi",
        "BS Social Work",
        "BS Urdu"
    ],

    "Faculty of Education": [
        "Education",
        "Special Education",
        "B.Ed (1 Year)",
        "B.Ed (Hons) (4 Year)"
    ],

    "Faculty of Science & Technology": [
        "BS Biochemistry",
        "BS Botany",
        "BS Statistics",
        "BS Chemistry",
        "BS Computer Science",
        "BS Environmental Science",
        "BS Geography",
        "BS Geology",
        "BS Mathematical Sciences",
        "BS Microbiology",
        "BS Physics",
        "Statistics with Finance",
        "BS Zoology",
        "BS Biotechnology",
        "BS Sport Science"
    ],

    "Faculty of Pharmacy": [
        "Pharm.D (5 Years)"
    ],

    "Faculty of Business Administration, Commerce & Economics": [
        "BBA",
        "BS Business Administration",
        "BS Commerce (4 Years)",
        "B.Com (2 Years)",
        "BS Economics (4 Years)",
        "BA Economics (2 Years)"
    ],

    "Faculty of Islamic Studies": [
        "Islamic Learning"
    ],

    "Faculty of Law": [
        "B.A-LLB (5 Years)"
    ]
}


computer_science = {

    "department": "Department of Computer Science",

    "programs": [
        "BS Computer Science",
        "BS Artificial Intelligence",
        "BS Cyber Security"
    ],

    "research_areas": [
        "Information Systems",
        "Artificial Intelligence",
        "Data Science",
        "Machine Learning",
        "Software Development",
        "Project Management",
        "Human Computer Interaction",
        "Statistics and Statistical Computing"
    ]
}


admission_info = {

    "general_eligibility": {
        "arts_education_theology": "Minimum 45% marks or as specified by the concerned program.",
        "other_faculties": "Generally minimum 50% marks, subject to the specific program eligibility."
    },

    "computer_science": {

        "BS Computer Science": {
            "minimum_marks": "50% in Intermediate/HSSC",
            "eligible_groups": [
                "Pre-Engineering",
                "Pre-Medical",
                "Science General"
            ],
            "admission_basis": {
                "entry_test": "50%",
                "intermediate_hssc": "30%",
                "matric_ssc": "20%"
            }
        },

        "BS Artificial Intelligence": {
            "minimum_marks": "50% in Intermediate/HSSC",
            "eligible_groups": [
                "Pre-Engineering",
                "Pre-Medical",
                "Science General"
            ],
            "admission_basis": {
                "entry_test": "50%",
                "intermediate_hssc": "30%",
                "matric_ssc": "20%"
            }
        },

        "BS Cyber Security": {
            "minimum_marks": "50% in Intermediate/HSSC",
            "eligible_groups": [
                "Pre-Engineering",
                "Pre-Medical",
                "Science General"
            ],
            "admission_basis": {
                "entry_test": "50%",
                "intermediate_hssc": "30%",
                "matric_ssc": "20%"
            }
        }
    },

    "entry_test": {
        "mandatory_for": [
            "BS Computer Science",
            "BS Artificial Intelligence",
            "BS Cyber Security",
            "BBA",
            "Pharm.D"
        ],

        "format": "50 MCQs",

        "general_topics": [
            "English",
            "Physics",
            "Chemistry",
            "Mathematics",
            "Biology",
            "Computer Science",
            "General Knowledge"
        ]
    }
}


fee_information = {

    "BS Computer Science": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 71,500",
        "semester_fee": "Rs. 55,000"
    },

    "BS Artificial Intelligence": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 76,500",
        "semester_fee": "Rs. 60,000"
    },

    "BS Cyber Security": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 76,500",
        "semester_fee": "Rs. 60,000"
    },

    "BBA": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 69,600",
        "semester_fee": "Rs. 53,100"
    },

    "BS Commerce": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 46,800",
        "semester_fee": "Rs. 30,300"
    },

    "BS Economics": {
        "other_charges": "Rs. 16,500",
        "admission_time": "Rs. 42,000",
        "semester_fee": "Rs. 25,500"
    }
}


student_services = {
    "services": [
        "Admissions",
        "Examinations",
        "Student Portal",
        "Enrollment Portal",
        "Library",
        "Degree-related services",
        "Student affairs"
    ]
}


facilities = [
    "Library",
    "Computer Labs",
    "Laboratories",
    "Student Portal",
    "Enrollment Portal",
    "Digital Library Resources"
]


fuuast_knowledge = {
    "University Information": university_info,
    "Campuses": campuses,
    "Undergraduate Programs": undergraduate_programs,
    "Computer Science Department": computer_science,
    "Admission Information": admission_info,
    "Fee Information": fee_information,
    "Student Services": student_services,
    "Facilities": facilities
}


def fuuast_agent(user_input):

    prompt = f"""
You are an AI Knowledge Assistant for Federal Urdu University
of Arts, Sciences & Technology (FUUAST).

Your job is to answer students' questions about FUUAST.

{fuuast_knowledge}

Answer the student's question using the provided information.

Do not invent or guess FUUAST information.

If the requested information is not available, say:
"Sorry, this information is not available in my current FUUAST knowledge base."

Keep the answer simple, clear, and student-friendly.

Student Question:
{user_input}

Answer:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("FUUAST AI Knowledge Assistant Started")
print("Type 'exit' to stop.\n")

while True:

    user = input("You: ")

    if user.lower().strip() == "exit":
        print("Goodbye!")
        break

    try:

        answer = fuuast_agent(user)

        print("\nFUUAST Assistant:")
        print(answer)
        print()

    except Exception as e:

        print("Error:", e)
# Out:
# ERROR: Operation cancelled by user
# FUUAST AI Knowledge Assistant Started
# Type 'exit' to stop.
#
# You: What programs are offered by FUUAST?
#
# FUUAST Assistant:
# FUUAST offers a variety of undergraduate programs across different faculties and departments:
#
# **Faculty of Arts:**
# * BS Arabic
# * BS English
# * BS General History
# * BS International Relations
# * BS Islamic History
# * BS Mass Communication
# * BS Political Science
# * BS Psychology
# * BS Sindhi
# * BS Social Work
# * BS Urdu
#
# **Faculty of Education:**
# * Education
# * Special Education
# * B.Ed (1 Year)
# * B.Ed (Hons) (4 Year)
#
# **Faculty of Science & Technology:**
# * BS Biochemistry
# * BS Botany
# * BS Statistics
# * BS Chemistry
# * BS Computer Science
# * BS Environmental Science
# * BS Geography
# * BS Geology
# * BS Mathematical Sciences
# * BS Microbiology
# * BS Physics
# * Statistics with Finance
# * BS Zoology
# * BS Biotechnology
# * BS Sport Science
#
# ...
