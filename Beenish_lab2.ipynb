# %% [markdown]
# <a href="https://colab.research.google.com/github/beenishkhan919-bs/15052041/blob/main/Beenish_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip.install -Ugoogle-genai
# Out:
# /bin/bash: line 1: pip.install: command not found

# %%
from google import genai

# %%
from google import genai

Client = genai.Client(api_key="Beenish_apikey")

# %%
MODEL = "models/gemini-3.6-flash"

# %%
print("Gemini Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    response = client.models.generate_content(
        model="models/gemini-3.6-flash",
        contents=user_input
    )

    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: Bye
# Chatbot: Goodbye 👋
